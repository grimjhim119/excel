# %%
import nbformat as nbf
from nbformat.v4 import new_notebook, new_markdown_cell

nb = new_notebook()
cells = []

# Question 1
cells.append(new_markdown_cell("""
## Question 1:
**What is the difference between 'Paste' and 'Paste Special' in Excel? Briefly explain with examples.**

**Answer:**
- **Paste:** Used to copy all contents (values, formulas, formats) from one cell to another.
  Example: Copying `=A1+B1` will paste the formula itself.

- **Paste Special:** Allows selective pasting — you can paste only **values**, **formats**, **formulas**, or **comments**.
  Example: Copying `=A1+B1` and using *Paste Special → Values* will paste only the result, not the formula.

🖼️ *Insert Screenshot Here*
"""))

# Question 2
cells.append(new_markdown_cell("""
## Question 2:
**Describe the functions and usefulness of 'Freeze Panes' and 'Split Panes' in Excel.**

**Answer:**
- **Freeze Panes:** Keeps specific rows/columns visible while scrolling. Helpful when working with large datasets.
  Example: Freezing the header row so it remains visible.

- **Split Panes:** Divides the worksheet into multiple sections, allowing simultaneous scrolling in different parts.
  Example: Compare two sections of a large spreadsheet side by side.

🖼️ *Insert Screenshot Here*
"""))

# Question 3
cells.append(new_markdown_cell("""
## Question 3:
**Explain the difference between inserting a new row and inserting a new column in Excel. Can you insert multiple rows or columns at once?**

**Answer:**
- **Inserting a Row:** Adds a new horizontal row below the selected cell.
- **Inserting a Column:** Adds a new vertical column to the left of the selected column.
- You can insert multiple rows/columns by selecting multiple existing ones and then clicking **Insert**.

🖼️ *Insert Screenshot (Before & After)*
"""))

# Question 4
cells.append(new_markdown_cell("""
## Question 4:
**What are logical functions in Excel? Provide examples of at least two logical functions and their applications.**

**Answer:**
Logical functions return results based on conditions. Common examples:

1. **IF()** → Checks a condition and returns one value if TRUE, another if FALSE.
   Example: `=IF(A1>50, "Pass", "Fail")`
2. **AND() / OR()** → Combine multiple conditions.
   Example: `=AND(A1>50, B1>60)` returns TRUE only if both are true.

🖼️ *Insert Screenshot of Example*
"""))

# Question 5
cells.append(new_markdown_cell("""
## Question 5:
**Discuss the purpose of 'XLOOKUP' and how it differs from the traditional 'VLOOKUP' function.**

**Answer:**
- **XLOOKUP:** Searches a range or array for a match and returns the corresponding value from another range. It replaces older lookup functions.
- **Difference:**
  - XLOOKUP works **left or right** of lookup value, while VLOOKUP only works **rightward**.
  - XLOOKUP doesn't require column index numbers.
  - Syntax: `=XLOOKUP(lookup_value, lookup_array, return_array, [if_not_found])`

🖼️ *Insert Screenshot Showing Example*
"""))

# Question 6
cells.append(new_markdown_cell("""
## Question 6:
**Create a worksheet titled 'Employee Data' with columns: Name, Age, Department. Add 5 rows of data. Format as follows:**
- Bold and center-align the header row
- Apply a fill color
- Auto-fit column width

**Answer:**
Example Table:

| Name | Age | Department |
|------|-----|-------------|
| Riya | 25  | HR |
| Aman | 29  | IT |
| Kavya | 30 | Marketing |
| Rohit | 28 | Finance |
| Meera | 26 | Admin |

🖼️ *Insert Screenshot of Excel Table*
"""))

# Question 7
cells.append(new_markdown_cell("""
## Question 7:
**Demonstrate how to insert and delete multiple rows and columns in Excel.**

**Answer:**
1. Select multiple rows or columns.
2. Right-click → *Insert* or *Delete*.
3. You can also use shortcuts:
   - Insert Row: `Ctrl` + `Shift` + `+`
   - Delete Row: `Ctrl` + `-`

🖼️ *Insert Screenshot Before and After*
"""))

# Question 8
cells.append(new_markdown_cell("""
## Question 8:
**Use Excel's 'Find and Replace' feature to update department names in a sample table.**

**Answer:**
- Shortcut: `Ctrl + H` opens *Find and Replace*.
- Example: Replace *HR* with *Human Resources*.
- Useful for updating large datasets quickly.

🖼️ *Insert Screenshot Showing Replaced Data*
"""))

# Question 9
cells.append(new_markdown_cell("""
## Question 9:
**Create a small numerical dataset and apply the following functions: AVERAGE, MAX, MIN.**

**Answer:**
Example Dataset:

| Value |
|--------|
| 45 |
| 67 |
| 80 |
| 72 |
| 60 |

Formulas:
- `=AVERAGE(A1:A5)` → Average = 64.8
- `=MAX(A1:A5)` → Max = 80
- `=MIN(A1:A5)` → Min = 45

🖼️ *Insert Screenshot Showing Formulas and Results*
"""))

# Question 10
cells.append(new_markdown_cell("""
## Question 10:
**You're working with a dataset that contains missing values. As a Data Scientist, explain how you'd detect and handle missing data using Excel. Mention tools like Go To Special, ISBLANK, COUNTBLANK.**

**Answer:**
- **Detect Missing Data:**
  - Use *Go To Special → Blanks* to highlight all empty cells.
- **Functions:**
  - `=ISBLANK(A1)` → Returns TRUE if the cell is empty.
  - `=COUNTBLANK(A1:A10)` → Counts how many cells are blank.
- **Handling Missing Data:**
  - Fill with `0`, averages, or previous values using Excel formulas.
  - Delete incomplete rows if necessary.

🖼️ *Insert Screenshot Showing Blank Cell Handling*
"""))
